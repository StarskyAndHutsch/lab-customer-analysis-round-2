# %% [markdown]
# ## Lab | Customer Analysis Round 2

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('marketing_customer_analysis.csv')
data.tail(50)

# %%
data.shape

# %%
column_names = data.columns
column_names

# %%
cols = []   
for column in data.columns:
    cols.append(column.lower())
data.columns = cols
data

# %%
data.dtypes

# %%
data._get_numeric_data()

# %%
data.select_dtypes(include=[object])

# %%
data.isna().sum() #

# %%
data['state'].value_counts(dropna=False)

# %%
data ['effective to date'] = pd.to_datetime (data ['effective to date'])

# %%
data

# %%
data ['month'] = data ['effective to date'].dt.month

# %%
data

# %%
data ['vehicle type'] .value_counts(dropna=False)

# %%
data ['vehicle size'] .value_counts(dropna=False)

# %%
data ['vehicle class'] .value_counts(dropna=False)

# %%
data['vehicle type'] = data['vehicle type'].fillna('M')

# %%
data
# Out:
#        unnamed: 0 customer       state  customer lifetime value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        coverage education effective to date employmentstatus gender  ...  \
# ...

# %%
data ['vehicle type'] .value_counts(dropna=False)
# Out:
# M    5482
# A    5428
# Name: vehicle type, dtype: int64

# %%
"""After - with Queen Erin's help - the problem of the vehicle types could be solved, it turns out that no changes have occurred in the other NaN. 

There are three groups
A. state & response - 631 each
B. months since last claim & number of open complaints - 633 each
C. vehicle class & vehicle size - 622 each

There seems to be no direct relationship between the groups. Within the groups, however, there are.

A. Persons may have moved unknown
B. No claim, no complain - logical! 
C. No more exact specification of the size, thus also none of the Class, and/or no assignment under the existing sizes possible.

For A: new column - unknown warped
For B: set both data to 0 
For C: ...

Have to make a break here, will continue tomorrow! 

"""
# Out:
# "After - with Queen Erin's help - the problem of the vehicle types could be solved, it turns out that no changes have occurred in the other NaN. \n\nThere are three groups\nA. state & response - 631 each\nB. months since last claim & number of open complaints - 633 each\nC. vehicle class & vehicle size - 622 each\n\nThere seems to be no direct relationship between the groups. Within the groups, however, there are.\n\nA. Persons may have moved unknown\nB. No claim, no complain - logical! \nC. No more exact specification of the size, thus also none of the Class, and/or no assignment under the existing sizes possible.\n\nFor A: new column - unknown warped\nFor B: set both data to 0 \nFor C: ...\n\nHave to make a break here, will continue tomorrow! \n\n"

# %% [markdown]
# # Playground¶

# %%
data.isna().sum()
# Out:
# unnamed: 0                         0
# customer                           0
# state                            631
# customer lifetime value            0
# response                         631
# coverage                           0
# education                          0
# effective to date                  0
# employmentstatus                   0
# gender                             0
# income                             0
# location code                      0
# marital status                     0
# monthly premium auto               0
# months since policy inception      0
# number of policies                 0
# policy type                        0
# policy                             0
# renew offer type                   0
# sales channel                      0
# total claim amount                 0
# vehicle class                    622
# vehicle size                     622
# vehicle type                       0
# month                              0
# dtype: int64

# %%
data ['months since last claim'] .value_counts(dropna=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'months since last claim'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
data ['number of open complaints'] .value_counts(dropna=False)

# %%
# !pip3 install seaborn if you need to
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# %%
data=data.drop(['number of open complaints'], axis=1)
sns.pairplot(data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [39], in <cell line: 1>()
# ----> 1 data=data.drop(['number of open complaints'], axis=1)
#       2 sns.pairplot(data)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
# ...

# %%
data=data.drop(['months since last claim'], axis=1)
sns.pairplot(data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [40], in <cell line: 1>()
# ----> 1 data=data.drop(['months since last claim'], axis=1)
#       2 sns.pairplot(data)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
# ...

# %%
data.loc

# %%
data.loc[:, data.isna().any()]
# Out:
#             state response  vehicle class vehicle size
# 0         Arizona       No  Four-Door Car      Medsize
# 1      California       No  Four-Door Car      Medsize
# 2      Washington       No            SUV      Medsize
# 3          Oregon      Yes  Four-Door Car      Medsize
# 4          Oregon       No  Four-Door Car      Medsize
# ...           ...      ...            ...          ...
# 10905      Nevada       No     Luxury Car      Medsize
# 10906      Oregon       No  Four-Door Car      Medsize
# 10907     Arizona       No     Luxury SUV      Medsize
# 10908  California       No            SUV      Medsize
# 10909         NaN      NaN            SUV      Medsize
#
# [10910 rows x 4 columns]

# %%
data[data.isna().any(axis=1)]
# Out:
#        unnamed: 0 customer       state  customer lifetime value response  \
# 5               5  HO81102         NaN              4745.181764      NaN
# 11             11  GE63585         NaN              2420.711888      NaN
# 58             58  BR69566         NaN             14019.833140      NaN
# 62             62  UF44021         NaN              2108.493744      NaN
# 87             87  ZH92587      Oregon              8126.766397       No
# ...           ...      ...         ...                      ...      ...
# 10879       10879  FK95213  California             18611.453560       No
# 10883       10883  FD64348      Oregon             22563.618380       No
# 10890       10890  VQ78876      Oregon              4660.399573       No
# 10894       10894  EX63393         NaN              6314.492009      NaN
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        coverage             education effective to date employmentstatus  \
# ...

# %%
data[df.isna().any(axis=1)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [44], in <cell line: 1>()
# ----> 1 data[df.isna().any(axis=1)]
#
# NameError: name 'df' is not defined

# %% [markdown]
# #  Lab | Customer Analysis Round 3

# %%
data.select_dtypes(np.number)
# Out:
#        unnamed: 0  customer lifetime value  income  monthly premium auto  \
# 0               0              4809.216960   48029                    61
# 1               1              2228.525238       0                    64
# 2               2             14947.917300   22139                   100
# 3               3             22332.439460   49078                    97
# 4               4              9025.067525   23675                   117
# ...           ...                      ...     ...                   ...
# 10905       10905             15563.369440       0                   253
# 10906       10906              5259.444853   61146                    65
# 10907       10907             23893.304100   39837                   201
# 10908       10908             11971.977650   64195                   158
# 10909       10909              6857.519928       0                   101
#
#        months since policy inception  number of policies  total claim amount  \
# ...

# %%
numerical=data.select_dtypes(np.number)

# %%
numerical.head()
# Out:
#    unnamed: 0  customer lifetime value  income  monthly premium auto  \
# 0           0              4809.216960   48029                    61
# 1           1              2228.525238       0                    64
# 2           2             14947.917300   22139                   100
# 3           3             22332.439460   49078                    97
# 4           4              9025.067525   23675                   117
#
#    months since policy inception  number of policies  total claim amount  \
# 0                             52                   9          292.800000
# 1                             26                   1          744.924331
# 2                             31                   2          480.000000
# 3                              3                   2          484.013411
# 4                             31                   7          707.925645
#
#    month
# 0      2
# 1      1
# 2      2
# 3      1
# 4      1

# %%
categorical=data.select_dtypes(object)

# %%
categorical.head()
# Out:
#   customer       state response  coverage education employmentstatus gender  \
# 0  DK49336     Arizona       No     Basic   College         Employed      M
# 1  KX64629  California       No     Basic   College       Unemployed      F
# 2  LZ68649  Washington       No     Basic  Bachelor         Employed      M
# 3  XL78013      Oregon      Yes  Extended   College         Employed      M
# 4  QA50777      Oregon       No   Premium  Bachelor    Medical Leave      F
#
#   location code marital status     policy type        policy renew offer type  \
# 0      Suburban        Married  Corporate Auto  Corporate L3           Offer3
# 1      Suburban         Single   Personal Auto   Personal L3           Offer4
# 2      Suburban         Single   Personal Auto   Personal L3           Offer3
# 3      Suburban         Single  Corporate Auto  Corporate L3           Offer2
# 4      Suburban        Married   Personal Auto   Personal L2           Offer1
#
# ...

# %%
sns.pairplot(numerical) 
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#normality found for: 
#monthly premuim auto / total claim amount
#monthly premuim auto / customer lifetime
#income / customer lifetime value
#total claim amount / monthly premium auto

# %%
plt.figure(figsize=(10,5))
correlations_matrix = numerical.corr()
sns.heatmap(correlations_matrix, annot=True)
plt.show()

# %% [markdown]
# ## Lab | Customer Analysis Round 4

# %% [markdown]
# ## Lab | Customer Analysis Round 5

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
numerical.describe().T
# Out:
#                                  count          mean           std  \
# unnamed: 0                     10910.0   5454.500000   3149.590053
# customer lifetime value        10910.0   8018.241094   6885.081434
# income                         10910.0  37536.284785  30359.195670
# monthly premium auto           10910.0     93.196059     34.442532
# months since policy inception  10910.0     48.091934     27.940675
# number of policies             10910.0      2.979193      2.399359
# total claim amount             10910.0    434.888330    292.180556
# month                          10910.0      1.466728      0.498915
#
#                                        min          25%           50%  \
# unnamed: 0                        0.000000  2727.250000   5454.500000
# customer lifetime value        1898.007675  4014.453113   5771.147235
# income                            0.000000     0.000000  33813.500000
# monthly premium auto             61.000000    68.000000     83.000000
# ...

# %%
#y = total claim amount
#X = without total claim amount

y = numerical['total claim amount']
X = numerical.drop(['total claim amount'], axis=1)

# %%
lm = linear_model.LinearRegression()
lm. fit(X,y)
print(lm.score(X,y))
# Out:
# 0.5205264585733143

# %%
numerical.corr()
# Out:
#                                unnamed: 0  customer lifetime value    income  \
# unnamed: 0                       1.000000                 0.001355  0.008910
# customer lifetime value          0.001355                 1.000000  0.028306
# income                           0.008910                 0.028306  1.000000
# monthly premium auto             0.000863                 0.403069 -0.009788
# months since policy inception    0.012795                 0.016960 -0.005903
# number of policies               0.002319                 0.016024 -0.009960
# total claim amount              -0.000593                 0.232626 -0.354141
# month                            0.004755                -0.009234 -0.000443
#
#                                monthly premium auto  \
# unnamed: 0                                 0.000863
# customer lifetime value                    0.403069
# income                                    -0.009788
# monthly premium auto                       1.000000
# ...

# %%
sns.scatterplot(x=numerical['monthly premium auto'], y=numerical['total claim amount'])
plt.show()

# %%
#thx to jesus
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

transformer = MinMaxScaler().fit(X)
x_normalized = transformer.transform(X)
print(x_normalized.shape)
x_normalized
df = pd.DataFrame(x_normalized, columns=X.columns)
# Out:
# (10910, 7)

# %%
sns.scatterplot(x=numerical['monthly premium auto'], y=numerical['total claim amount'])
plt.show()
